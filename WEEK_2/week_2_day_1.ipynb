# %%
# machine learning is the field of study where it provides the opportunity to the computers to learn patterns from data and give insights / decisions without explicitly programmed..
# Types of Programming are: 1) Traditional Programming 2) Machine learning
#1. Traditional Programming: In this, the input data and manually written rules which then computed by computer to give output / answers.. Its key points are: less flexibility, limited scalibilty , it falls when rules are manually written complex
#2. Machine Learning: In this, it is the correlation between the data that it learn patterns from historical data and give answers to it.

#Four types of ML:
#1 Supervised Learning: The main mechanism is that it learns data from labelled dataset; example: predicting house rents using historical labelled data etc.. ; It also tells the relationship between the dependent variable (target) and the two or more independent variable (input)

#2. Un Supervised L.: The main mechanism is that it learns the hidden data patterns from un-labelled dataset; example: e commerce customer segregation...

#3 Reinforcement L: In this, an agent learns via trial or error using rewards and penalties in an environment..

#4. Semi supervised learning: both supervised and un serpervised learning...; it combines small labelled data with massive amount of unlabelled data....

#Learning algo:
#1. Supervised learning: Regression: It includes linear or logistic to determine the continuous numerical value that refers the rel btw the dependent var and two or more independent var...; It also create a straight line to determine the data points
#classification:  It is used to classify the different data points on their diiff classes, that separates two different classes via straight line........ use cases: span or non span, face recognition etc


#Un Supervised Learning: Clustering: main aim is to divide the data points into the various clusters to find the hidden patterns from data


#----------------------------------------------------
#end to end ML Life cycle:
#1. Problem Def.
#2. Data Collection
#3. Data Cleaning
#--these above are done by data engineers---
#4. EDA
#5. Feature Engg. (specify certain features like taking input and target and then merge them to make prediction later on.)
#6. Model selection
#--these above are done by ML Engineers---
#7. model training
#8. model testing
#9. deployment
#10. maintenance and monitoring
#---these above are done by Devops engineer---

#In model traing and testing the split are in ratio: 80 - 20 %, 70 -30 %

#-----------------------------------------------------


#Phase: Feature engineering and data splitting
#Feature engg: In this, it transforms the raw data into optimised numerical input features (scaling, normalisation, encoding categorical features)
#data splitting: In this, it splits the data into two major splits : 80 - 20 % and 70 - 30 % splits ....


#-----------------------------------------------------

#once model training is done but during training some challenges faced by model :
#Overfitting: In this, the model memorizes / learn patterns from data too much (learning noise and outliers) that it lacks to predict answer for real world scenarios
#Underfitting: In this, model fails to learn patterns from data
#Good fit: In this,the model captures the correct trend of data and give correct predictions for the trained data..

#It tells the bias and variance relationship in term of underfitting and overfitting:
#High bias and low variance means Underfitting
#low bias and high variance means Overfitting


#------------------------------------------------------


#Extraction engine: Web Scrapping

#1. Find target website for data collection
#2. receive html
#3. parse engine which parse document and extract notes/ data
#4. once extracted the data we find raw data
#5. then we make raw data into structured csv file format for further data processing..

#------------------------------------------------------

# %%
#correlation analysis

#it used in visualising in the EDA (heatmap) to show the correlation between the variables

# %%
#python PDA ecosystem

#1. enterprise optimisation layer -> 2. visualisation layer (matplotlib, seaborn, plotly) -> 3. data validation -> 4. evaluation

#Box plot anatomy:
# the IQR(interquartile range) = Q3 -Q1 where Q3 IS THE 75 % PERCENTILE AND Q1 IS THE 25% PERCENTILE .. and the middle value is median (50% percentile)
# the maximum value is Q3 + 1.5 * IQR
# the minimum value is Q1 +1.5 * IQR

#it is in seaborn library

#search for box plot and violin plot

# %%
#outlier resolution matrix

#Z score method: formula: z=(x - variance ) / standard derivation

#------------------------------------------

# %%
#scaling matrix : normalisation vs standardization

#min max normalisation
# x dash = x - x min / x max - x min

#z score standardization
#z = x - variance / standard derivation

#search about this***

# %%
#feature extraction: capturing vision -> basic for DL

#images contain dense pixel information; extraction include shapes, edges, textures and patterns to make a vision readable for machines to get prediction afterwards...

#each real world images include pixels that further distributes into three layers red, green , blue {rgb} -> for red : (255,0,0), green: (0,255,0), blue : (0,0,255)
#flow for image processing = raw image -> edge detection -> cnn feature map

#----------
#conversion of grayscale to rgb and vice versa
#----------

# %%
#feature transformation: encoding categorical data

#encoding matrix:
#label encoding: applicable when there is two variable
#one hot encoding: applicable when there is more than two variable

#It uses simply to convert text /categorical data in the form of strings into numerical (numbers) format

# %%
#dimenstionality reduction
