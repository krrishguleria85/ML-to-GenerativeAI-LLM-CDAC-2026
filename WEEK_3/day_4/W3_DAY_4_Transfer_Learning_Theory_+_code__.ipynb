# %% [markdown]
# TRANSFER LEARNING MODELS

# %%
#TRANSFER LEARNING MODELS IN DEEP LEARNING
#============================================================
#Transfer Learning is a Deep Learning technique where a model pre-trained on a large dataset (such as ImageNet) is reused for a new task instead of training a neural network from scratch.

#ImageNet Dataset:

#14+ Million Images
#1000 Classes

#Benefits: ✓ Faster Training ✓ Less Data Requirement ✓ Better Accuracy ✓ Reduced Computational Cost

# %%
# feature extraction leayers: early layer , middle , deep layer

# Variants of transfer learning:


#1. VGG = Visual Geometry Group Developed By: University of Oxford

#Models:
#VGG16
#VGG19
#Full Forms: VGG16 = Visual Geometry Group 16 Layer Network VGG19 = Visual Geometry Group 19 Layer Network

#Characteristics:
#Simple Architecture
#Uses 3x3 Convolution Filters
#Easy to Understand
#High Number of Parameters
#Input Size: 224 × 224 × 3

#Use Cases: ✓ Image Classification ✓ Transfer Learning Education ✓ Feature Extraction ✓ Medical Imaging

#Advantages: ✓ Easy to Implement ✓ Good Baseline Model

#Limitations: ✗ Large Model Size ✗ Slow Training

# %%
#2. RESNET FAMILY: Residual Neural Network developed by: Microsoft research

#models:
#ResNet18
#ResNet34
#ResNet50
#ResNet101
#ResNet152

#Full Forms: ResNet18 = Residual Network with 18 Layers ResNet34 = Residual Network with 34 Layers ResNet50 = Residual Network with 50 Layers ResNet101 = Residual Network with 101 Layers ResNet152 = Residual Network with 152 Layers

#Key Innovation: Residual Connections (Skip Connections)

#Use Cases: ✓ Image Classification ✓ Object Detection ✓ Face Recognition ✓ Medical Imaging ✓ Industrial AI Systems
#Advantages: ✓ Solves Vanishing Gradient Problem ✓ Supports Very Deep Networks ✓ High Accuracy

#Most Popular: ResNet50

# %%
# 3. INCEPTION FAMILY: Google net architecture developed by google
# full forms: Inception: Network with multiple filter sizes ; GoogleNet: google deep learning network

# Characteristics:

#Multiple Convolution Filters in Parallel
#Efficient Architecture
#Reduced Computation
#Input Size: 299 × 299 × 3

#Use Cases: ✓ Image Classification ✓ Object Detection ✓ Scene Understanding

#Advantages: ✓ Efficient Computation ✓ Better Accuracy than VGG

# %%
#4. Xception = Extreme Inception

#Developed By: Google

#Characteristics:

#Depthwise Separable Convolutions
#Improved Inception Architecture
#Input Size: 299 × 299 × 3

#Use Cases: ✓ Medical Imaging ✓ Satellite Image Analysis ✓ Industrial Defect Detection

#Advantages: ✓ Faster than Inception ✓ Better Accuracy

# %%
#5. DENSENET FAMILY

#DenseNet = Densely Connected Convolutional Network

#Models:

#DenseNet121
#DenseNet169
#DenseNet201
#Full Forms: DenseNet121 = Dense Network with 121 Layers DenseNet169 = Dense Network with 169 Layers DenseNet201 = Dense Network with 201 Layers

#Characteristics:

#Every Layer Connected to Every Other Layer
#Feature Reuse
#Use Cases: ✓ Medical Image Analysis ✓ Feature Extraction ✓ Computer Vision Research

#Advantages: ✓ Efficient Learning ✓ Less Parameters ✓ Better Gradient Flow

#Most Popular: DenseNet121

# %%
# 6. MOBILENET FAMILY:

# MobileNet = Mobile Neural Network

#Models:

#MobileNet
#MobileNetV2
#MobileNetV3
#Developed By: Google

#Characteristics:

#Lightweight Architecture
#Optimized for Mobile Devices
#Use Cases: ✓ Mobile Applications ✓ Embedded Systems ✓ Edge AI ✓ Real-Time Detection

#Advantages: ✓ Very Fast ✓ Small Model Size ✓ Low Memory Usage

#Most Popular: MobileNetV2

# %% [markdown]
# 7. EFFICIENTNET FAMILY
# ============================================================
# EfficientNet = Efficient Neural Network
#
# Developed By: Google Brain
#
# Models:
#
# EfficientNetB0
# EfficientNetB1
# EfficientNetB2
# EfficientNetB3
# EfficientNetB4
# EfficientNetB5
# EfficientNetB6
# EfficientNetB7
# Full Forms: B = Baseline Scaling Version
#
# Characteristics:
#
# Compound Scaling
# Scales Depth, Width and Resolution Together
# Use Cases: ✓ Medical Imaging ✓ Plant Disease Detection ✓ Industrial AI ✓ Computer Vision Competitions
#
# Advantages: ✓ Excellent Accuracy ✓ Less Parameters ✓ State-of-the-Art Performance
#
# Most Popular: EfficientNetB0 EfficientNetB3 EfficientNetB4
#
#
#
# 8. NASNET FAMILY
# ============================================================
# NASNet = Neural Architecture Search Network
#
# Models:
#
# NASNetMobile
# NASNetLarge
# Characteristics:
#
# Architecture Generated Automatically
# AI Designed CNN Architecture
# Use Cases: ✓ Advanced Research ✓ AutoML Systems
#
# Advantages: ✓ High Accuracy ✓ Automated Design
#
#
# 9. CONVNEXT FAMILY
# ============================================================
# ConvNeXt = Convolutional Next Generation Network
#
# Models:
#
# ConvNeXt Tiny
# ConvNeXt Small
# ConvNeXt Base
# ConvNeXt Large
# Characteristics:
#
# Modernized CNN Architecture
# CNN Alternative to Transformers
# Use Cases: ✓ Image Classification ✓ Object Detection ✓ Segmentation
#
# Advantages: ✓ Modern CNN Design ✓ High Accuracy
#
#
#
#
# 10. VISION TRANSFORMER FAMILY
# ============================================================
# ViT = Vision Transformer
#
# Models:
#
# ViT-B16
# ViT-B32
# ViT-L16
# ViT-L32
# Full Forms: ViT-B16 = Vision Transformer Base 16x16 Patches ViT-B32 = Vision Transformer Base 32x32 Patches ViT-L16 = Vision Transformer Large 16x16 Patches ViT-L32 = Vision Transformer Large 32x32 Patches
#
# Characteristics:
#
# Transformer-Based Architecture
# Uses Self-Attention
# Use Cases: ✓ Image Classification ✓ Image Retrieval ✓ Computer Vision Research
#
# Advantages: ✓ State-of-the-Art Performance ✓ Excellent Scalability
#
#
# 11. SWIN TRANSFORMER FAMILY
#
# Swin = Shifted Window Transformer
#
# Models:
#
# Swin Tiny
# Swin Small
# Swin Base
# Swin Large
# Characteristics:
#
# Hierarchical Transformer
# Window-Based Attention
# Use Cases: ✓ Image Classification ✓ Object Detection ✓ Semantic Segmentation ✓ Medical Imaging
#
# Advantages: ✓ High Performance ✓ Efficient Computation
#
#
# MOST POPULAR TRANSFER LEARNING MODELS
# ============================================================
# Beginner Level: ✓ VGG16 ✓ VGG19 ✓ MobileNetV2
#
# Intermediate Level: ✓ ResNet50 ✓ DenseNet121 ✓ EfficientNetB0
#
# Advanced Level: ✓ EfficientNetB3 ✓ EfficientNetB4 ✓ Xception ✓ ConvNeXt ✓ Vision Transformer (ViT) ✓ Swin Transformer

# %% [markdown]
# # Transfer Learning Models
#
# | Family | Full Form | Popular Models | Use Cases | Advantages |
# |----------|----------|----------|----------|----------|
# | VGG | Visual Geometry Group | VGG16, VGG19 | Image Classification, Feature Extraction, Medical Imaging | Simple Architecture, Easy to Learn |
# | ResNet | Residual Neural Network | ResNet18, ResNet34, ResNet50, ResNet101, ResNet152 | Classification, Object Detection, Face Recognition | Solves Vanishing Gradient Problem |
# | Inception | GoogLeNet / Inception Network | InceptionV1, InceptionV2, InceptionV3 | Classification, Object Detection, Scene Recognition | Efficient Computation |
# | Xception | Extreme Inception | Xception | Medical Imaging, Satellite Imaging | High Accuracy, Efficient Learning |
# | DenseNet | Densely Connected Network | DenseNet121, DenseNet169, DenseNet201 | Medical Imaging, Classification | Feature Reuse, Better Gradient Flow |
# | MobileNet | Mobile Neural Network | MobileNet, MobileNetV2, MobileNetV3 | Mobile Apps, Embedded Systems, Edge AI | Lightweight, Fast |
# | EfficientNet | Efficient Neural Network | EfficientNetB0-B7 | Medical Imaging, Plant Disease Detection, Industrial AI | Excellent Accuracy, Fewer Parameters |
# | NASNet | Neural Architecture Search Network | NASNetMobile, NASNetLarge | AutoML, Research | AI Designed Architecture |
# | ConvNeXt | Convolutional Next Generation Network | ConvNeXt Tiny, Small, Base, Large | Classification, Detection | Modern CNN Architecture |
# | ViT | Vision Transformer | ViT-B16, ViT-B32, ViT-L16, ViT-L32 | Classification, Image Retrieval | Transformer-Based Vision |
# | Swin Transformer | Shifted Window Transformer | Swin Tiny, Small, Base, Large | Detection, Segmentation, Classification | Hierarchical Transformer |

# %%
# intro to AlexNet: architecture of deep learning algo (important*)

#developed in 2012 and core innovation : first deep cnn model to significantly boost the model performance

# His impact on DL is 15.3% error rate on the ILSVRC 2012 Dataset which is nearly  40 % reduction in error than traditional methods

# AlexNet architecture overview: image data (227x227x3) ----> Conv1 with max pool ----> Conv1 with max pool ---->Conv3 + conv4 + conv 5 + max pool ----> flatten layer almost 3 with activation layer is softmax and then output....

# %%
# Unrolling the VGG16 architecture blueprint: exactly 16 weighted layers (13 conv + 3 fully connected) architecture is in net

# tensor progression : squeezing space, expanding depth by visualising the image as moves through the network and when we go further to the image so image matrix gets shorter but filter increases

# %%
# ResNet family : residual network by microsoft
# degradation pro:
# the expectation: more layers -> better feature extraction --> higher accuracy

# the reality: after certain depth the optimization should unstable and acc. drops

#------------------------

#In resnet block, there is skip connection to skip unwanted layers and move to further imp layers and it is good than traditional CNN..

# %%
# macro arch. : the googlenet topology (V1)
# GoogleNet stacks 9 repeating inception modules, to create a 22 layer deep network

# input(224x224x3) --> 7x7 conv ---> max pool ----> 3x3 conv ---> max pool ---> iterative extracts  ---> output

# %% [markdown]
# CODE (VGG 19) -> transfer learning

# %%
#import required libraries
import numpy as np
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential

# %%
# ============================================================
# INSTALL REQUIRED LIBRARIES
# ============================================================

# !pip install -q kagglehub
# !pip install -q split-folders

# ============================================================
# IMPORT LIBRARIES
# ============================================================

import kagglehub
import splitfolders
import os

from glob import glob

# ============================================================
# DOWNLOAD DATASET
# ============================================================

path = kagglehub.dataset_download(
    "alxmamaev/flowers-recognition"
)

print("Dataset Path:")
print(path)

# ============================================================
# FIND FLOWERS FOLDER
# ============================================================

if "flowers" in os.listdir(path):

    dataset_path = os.path.join(
        path,
        "flowers"
    )

else:

    dataset_path = path

print("\nDataset Folder:")
print(dataset_path)

# ============================================================
# CREATE TRAIN / VAL / TEST SPLIT
# ============================================================

splitfolders.ratio(

    dataset_path,

    output="Datasets",

    seed=42,

    ratio=(0.70,0.15,0.15)

)

print("\nDataset Split Completed")

# ============================================================
# VERIFY DATASET STRUCTURE
# ============================================================

print("\nTrain Classes")

print(
    os.listdir(
        "Datasets/train"
    )
)

print("\nValidation Classes")

print(
    os.listdir(
        "Datasets/val"
    )
)

print("\nTest Classes")

print(
    os.listdir(
        "Datasets/test"
    )
)

# ============================================================
# PATHS
# ============================================================

train_path = "Datasets/train"

valid_path = "Datasets/val"

test_path = "Datasets/test"

# ============================================================
# IMAGE SIZE
# ============================================================

IMAGE_SIZE = [224,224]

# ============================================================
# FIND CLASSES
# ============================================================

folders = glob(
    train_path + "/*"
)

print("\nClasses Found:")

for folder in folders:

    print(
        os.path.basename(folder)
    )

print(
    "\nTotal Classes:",
    len(folders)
)

print("\nDataset Ready For VGG19")
# Out:
# Using Colab cache for faster access to the 'flowers-recognition' dataset.
# Dataset Path:
# /kaggle/input/flowers-recognition
#
# Dataset Folder:
# /kaggle/input/flowers-recognition/flowers
# Copying files: 4317 files [00:30, 141.69 files/s]
# Dataset Split Completed
#
# Train Classes
# ['dandelion', 'sunflower', 'rose', 'tulip', 'daisy']
#
# Validation Classes
# ['dandelion', 'sunflower', 'rose', 'tulip', 'daisy']
#
# Test Classes
# ['dandelion', 'sunflower', 'rose', 'tulip', 'daisy']
#
# Classes Found:
# dandelion
# sunflower
# rose
# tulip
# daisy
#
# Total Classes: 5
#
# Dataset Ready For VGG19

# %%
# ============================================================
# MODULE 1
# FLOWERS DATASET EXPLORATION & PREPROCESSING
# ============================================================

# ============================================================
# SECTION 1: IMPORT LIBRARIES
# ============================================================

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf

import kagglehub
import splitfolders
import os
import random

from glob import glob

from tensorflow.keras.preprocessing.image import (
    ImageDataGenerator,
    load_img,
    img_to_array
)

print("TensorFlow Version:", tf.__version__)

# ============================================================
# SECTION 2: DATASET PATHS
# ============================================================

train_path = "Datasets/train"
valid_path = "Datasets/val"
test_path = "Datasets/test"

IMAGE_SIZE = (224,224)

# ============================================================
# SECTION 3: FIND CLASSES
# ============================================================

folders = glob(
    train_path + "/*"
)

class_names = []

for folder in folders:

    class_names.append(
        os.path.basename(folder)
    )

print("Classes Found")

for cls in class_names:

    print(cls)

print(
    "\nTotal Classes:",
    len(class_names)
)

# ============================================================
# SECTION 4: DATASET OVERVIEW
# ============================================================

dataset_info = []

for cls in class_names:

    train_count = len(
        os.listdir(
            os.path.join(
                train_path,
                cls
            )
        )
    )

    val_count = len(
        os.listdir(
            os.path.join(
                valid_path,
                cls
            )
        )
    )

    test_count = len(
        os.listdir(
            os.path.join(
                test_path,
                cls
            )
        )
    )

    total_count = (
        train_count +
        val_count +
        test_count
    )

    dataset_info.append(

        [
            cls,
            train_count,
            val_count,
            test_count,
            total_count
        ]

    )

dataset_df = pd.DataFrame(

    dataset_info,

    columns=[
        "Class",
        "Train",
        "Validation",
        "Test",
        "Total"
    ]

)

display(dataset_df)

# ============================================================
# SECTION 5: CLASS DISTRIBUTION
# ============================================================

plt.figure(
    figsize=(10,5)
)

sns.barplot(
    data=dataset_df,
    x="Class",
    y="Total"
)

plt.title(
    "Flowers Dataset Class Distribution"
)

plt.xlabel(
    "Flower Class"
)

plt.ylabel(
    "Number of Images"
)

plt.xticks(
    rotation=45
)

plt.show()

# ============================================================
# SECTION 6: RANDOM SAMPLE IMAGES
# ============================================================

plt.figure(
    figsize=(15,10)
)

for i, cls in enumerate(class_names):

    image_path = random.choice(

        glob(
            os.path.join(
                train_path,
                cls,
                "*"
            )
        )

    )

    image = load_img(
        image_path,
        target_size=IMAGE_SIZE
    )

    plt.subplot(
        2,
        3,
        i+1
    )

    plt.imshow(image)

    plt.title(cls)

    plt.axis("off")

plt.tight_layout()

plt.show()

# ============================================================
# SECTION 7: VISUALIZE 15 RANDOM FLOWERS
# ============================================================

all_images = glob(
    train_path + "/*/*"
)

random_images = random.sample(
    all_images,
    15
)

plt.figure(
    figsize=(15,10)
)

for i, image_path in enumerate(random_images):

    image = load_img(
        image_path,
        target_size=IMAGE_SIZE
    )

    class_name = image_path.split("/")[-2]

    plt.subplot(
        3,
        5,
        i+1
    )

    plt.imshow(image)

    plt.title(class_name)

    plt.axis("off")

plt.tight_layout()

plt.show()

# ============================================================
# SECTION 8: IMAGE SHAPE ANALYSIS
# ============================================================

sample_image_path = random.choice(
    all_images
)

sample_image = load_img(
    sample_image_path
)

sample_array = img_to_array(
    sample_image
)

print("Image Shape")

print(
    sample_array.shape
)

print(
    "\nHeight:",
    sample_array.shape[0]
)

print(
    "Width:",
    sample_array.shape[1]
)

print(
    "Channels:",
    sample_array.shape[2]
)

# ============================================================
# SECTION 9: RGB CHANNEL VISUALIZATION
# ============================================================

image = load_img(
    sample_image_path,
    target_size=IMAGE_SIZE
)

image = img_to_array(
    image
).astype("uint8")

plt.figure(
    figsize=(15,5)
)

plt.subplot(1,4,1)

plt.imshow(image)

plt.title("Original")

plt.axis("off")

plt.subplot(1,4,2)

plt.imshow(
    image[:,:,0],
    cmap="Reds"
)

plt.title("Red Channel")

plt.axis("off")

plt.subplot(1,4,3)

plt.imshow(
    image[:,:,1],
    cmap="Greens"
)

plt.title("Green Channel")

plt.axis("off")

plt.subplot(1,4,4)

plt.imshow(
    image[:,:,2],
    cmap="Blues"
)

plt.title("Blue Channel")

plt.axis("off")

plt.show()

# ============================================================
# SECTION 10: IMAGE AUGMENTATION VISUALIZATION
# ============================================================

augmentation = ImageDataGenerator(

    rotation_range=40,

    zoom_range=0.3,

    width_shift_range=0.2,

    height_shift_range=0.2,

    shear_range=0.2,

    horizontal_flip=True,

    fill_mode="nearest"

)

image = load_img(
    sample_image_path,
    target_size=IMAGE_SIZE
)

image = img_to_array(
    image
)

image = np.expand_dims(
    image,
    axis=0
)

plt.figure(
    figsize=(15,10)
)

for i, batch in enumerate(

    augmentation.flow(
        image,
        batch_size=1
    )

):

    plt.subplot(
        2,
        3,
        i+1
    )

    plt.imshow(
        batch[0].astype("uint8")
    )

    plt.axis("off")

    if i == 5:
        break

plt.suptitle(
    "Image Augmentation Examples"
)

plt.show()

# ============================================================
# SECTION 11: CREATE DATA GENERATORS
# ============================================================

train_datagen = ImageDataGenerator(

    rescale=1./255,

    rotation_range=20,

    zoom_range=0.2,

    shear_range=0.2,

    horizontal_flip=True

)

validation_datagen = ImageDataGenerator(

    rescale=1./255

)

test_datagen = ImageDataGenerator(

    rescale=1./255

)

# ============================================================
# SECTION 12: TRAINING GENERATOR
# ============================================================

training_set = train_datagen.flow_from_directory(

    train_path,

    target_size=IMAGE_SIZE,

    batch_size=32,

    class_mode="categorical"

)

# ============================================================
# SECTION 13: VALIDATION GENERATOR
# ============================================================

validation_set = validation_datagen.flow_from_directory(

    valid_path,

    target_size=IMAGE_SIZE,

    batch_size=32,

    class_mode="categorical"

)

# ============================================================
# SECTION 14: TEST GENERATOR
# ============================================================

test_set = test_datagen.flow_from_directory(

    test_path,

    target_size=IMAGE_SIZE,

    batch_size=32,

    class_mode="categorical",

    shuffle=False

)

# ============================================================
# SECTION 15: CLASS INDICES
# ============================================================

print("\nClass Indices")

print(
    training_set.class_indices
)

# ============================================================
# SECTION 16: VISUALIZE BATCH FROM GENERATOR
# ============================================================

images, labels = next(
    training_set
)

plt.figure(
    figsize=(15,10)
)

for i in range(16):

    plt.subplot(
        4,
        4,
        i+1
    )

    plt.imshow(
        images[i]
    )

    class_name = list(
        training_set.class_indices.keys()
    )[

        np.argmax(
            labels[i]
        )

    ]

    plt.title(
        class_name
    )

    plt.axis("off")

plt.tight_layout()

plt.show()

# ============================================================
# SECTION 17: DATASET STATISTICS
# ============================================================

print("\nTraining Samples")

print(
    training_set.samples
)

print("\nValidation Samples")

print(
    validation_set.samples
)

print("\nTesting Samples")

print(
    test_set.samples
)

print("\nNumber of Classes")

print(
    len(class_names)
)

# ============================================================
# SECTION 18: CLASS DISTRIBUTION PIE CHART
# ============================================================

plt.figure(
    figsize=(8,8)
)

plt.pie(

    dataset_df["Total"],

    labels=dataset_df["Class"],

    autopct="%1.1f%%"

)

plt.title(
    "Flower Class Distribution"
)

plt.show()

# ============================================================
# SECTION 19: PROJECT OVERVIEW
# ============================================================

print("="*60)

print("FLOWERS CLASSIFICATION PROJECT")

print("="*60)

print("Model       : VGG19 Transfer Learning")

print("Classes     :", len(class_names))

print("Image Size  :", IMAGE_SIZE)

print("Train Images:", training_set.samples)

print("Val Images  :", validation_set.samples)

print("Test Images :", test_set.samples)

print("="*60)

# ============================================================
# SECTION 20: MODULE 1 COMPLETED
# ============================================================

print("\nMODULE 1 COMPLETED SUCCESSFULLY")
print("Dataset Ready For VGG19 Transfer Learning")
# Out:
# TensorFlow Version: 2.20.0
# Classes Found
# dandelion
# sunflower
# rose
# tulip
# daisy
#
# Total Classes: 5
#        Class  Train  Validation  Test  Total
# 0  dandelion    736         157   159   1052
# 1  sunflower    513         109   111    733
# 2       rose    548         117   119    784
# 3      tulip    688         147   149    984
# 4      daisy    534         114   116    764
# Image Shape
# (333, 500, 3)
#
# Height: 333
# Width: 500
# Channels: 3
# Found 3019 images belonging to 5 classes.
# Found 644 images belonging to 5 classes.
# Found 654 images belonging to 5 classes.
#
# Class Indices
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}
# Training Samples
# 3019
#
# Validation Samples
# 644
#
# Testing Samples
# 654
#
# Number of Classes
# 5
# ...
# FLOWERS CLASSIFICATION PROJECT
# ...
# Model       : VGG19 Transfer Learning
# Classes     : 5
# Image Size  : (224, 224)
# Train Images: 3019
# Val Images  : 644
# Test Images : 654
# ...
#
# ...
